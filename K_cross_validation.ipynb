# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("/home/majji-vinaykumar/Documents/heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.shape
# Out:
# (303, 14)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df["target"].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
x = df.drop(columns="target",axis=1)
y = df["target"]

# %%
print(x)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %% [markdown]
# # Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2,stratify=y,random_state=3)

# %%
print(x_test.shape,x_train.shape,y_test.shape,y_train.shape)
# Out:
# (61, 13) (242, 13) (61,) (242,)

# %% [markdown]
# ### comparing performance of the models

# %%
models=[LogisticRegression(max_iter=1000),SVC(kernel="linear"),KNeighborsClassifier(),RandomForestClassifier()]

# %%
def compare_model_train_test():
    
    for model in models:
        model.fit(x_train,y_train)
        y_pred = model.predict(x_test)
        accuracy = accuracy_score(y_test,y_pred)
        print("accuray of",model,"=",accuracy)

# %%
compare_model_train_test()
# Out:
# accuray of LogisticRegression(max_iter=1000) = 0.7704918032786885
# accuray of SVC(kernel='linear') = 0.7704918032786885
# accuray of KNeighborsClassifier() = 0.6557377049180327
# accuray of RandomForestClassifier() = 0.7704918032786885

# %% [markdown]
# # Cross validation

# %% [markdown]
# ### logestic regression

# %%
cv_score_lr = cross_val_score(LogisticRegression(max_iter=1000),xy,,cv=5) # cv means how many splits
print(cv_score_lr)
mean_accuracy_lr = sum(cv_score_lr)/len(cv_score_lr)
mean_accuracy_lr = mean_accuracy_lr*100
mean_accuracy_lr = round(mean_accuracy_lr,2)
print("mean_accuracy: ",mean_accuracy_lr)
# Out:
# [0.80327869 0.86885246 0.85245902 0.86666667 0.75      ]
# mean_accuracy:  82.83

# %% [markdown]
# ### svc

# %%
cv_score_svc = cross_val_score(SVC(kernel="linear"),x,y,cv=5) # cv means how many splits
print(cv_score_svc)
mean_accuracy_svc = sum(cv_score_svc)/len(cv_score_svc)
mean_accuracy_svc = mean_accuracy_svc*100
mean_accuracy_svc = round(mean_accuracy_svc,2)
print("mean_accuracy: ",mean_accuracy_svc)
# Out:
# [0.81967213 0.8852459  0.80327869 0.86666667 0.76666667]
# mean_accuracy:  82.83

# %%
# same do this for remaining models

# %%
# create function to compare models
models=[LogisticRegression(max_iter=1000),SVC(kernel="linear"),KNeighborsClassifier(),RandomForestClassifier()]
def comape_crossval_score():
    for model in models:
        cv_score = cross_val_score(model,x,y,cv=5)
        mean_accuracy = sum(cv_score)/len(cv_score)
        mean_accuracy = mean_accuracy*100
        mean_accuracy = round(mean_accuracy,2)
        print("Cross validation accuracies for",model,"=",cv_score)
        print("mean_accuracy % for",model,"=",mean_accuracy)
        print("-------------------------------------")

# %%
comape_crossval_score()
# Out:
# Cross validation accuracies for LogisticRegression(max_iter=1000) = [0.80327869 0.86885246 0.85245902 0.86666667 0.75      ]
# mean_accuracy % for LogisticRegression(max_iter=1000) = 82.83
# -------------------------------------
# Cross validation accuracies for SVC(kernel='linear') = [0.81967213 0.8852459  0.80327869 0.86666667 0.76666667]
# mean_accuracy % for SVC(kernel='linear') = 82.83
# -------------------------------------
# Cross validation accuracies for KNeighborsClassifier() = [0.60655738 0.6557377  0.57377049 0.73333333 0.65      ]
# mean_accuracy % for KNeighborsClassifier() = 64.39
# -------------------------------------
# Cross validation accuracies for RandomForestClassifier() = [0.86885246 0.86885246 0.81967213 0.83333333 0.78333333]
# mean_accuracy % for RandomForestClassifier() = 83.48
# -------------------------------------
