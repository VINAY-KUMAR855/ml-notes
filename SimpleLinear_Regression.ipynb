# %%
#regressiontypes--simple, multiple, polynomial, decision tree, random forrest regression
#simpe---used in only two variables X,Y
#steps used is data preprocessing, fitting model to train data, predecting the results, visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("/home/majji-vinaykumar/Documents/simpleLinear.csv")

# %%
dataset.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   34323
# 1              1.3   35432
# 2              1.5   36541
# 3              2.0   37650
# 4              2.5   38759

# %%
dataset.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x = dataset.iloc[:,:1].values
y = dataset.iloc[:,-1].values

# %%
print(x,y)
# Out:
# [[1.1]
#  [1.3]
#  [1.5]
#  [2. ]
#  [2.5]
#  [2.6]
#  [2.9]
#  [3.9]
#  [4.9]
#  [5.9]
#  [6.9]
#  [7.9]
#  [8.9]
#  [9.9]] [34323 35432 36541 37650 38759 39868 40977 42086 43195 44304 45413 46522
#  47631 48740]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#check how model predict
y_pred = regressor.predict(x_test)

# %%
plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, regressor.predict(x_train),color="blue")
plt.xlabel('Experience')
plt.ylabel('Salay')
plt.show()

# %%
#visualising test data
plt.scatter(x_test,y_test, color='red')
plt.plot(x_test, regressor.predict(x_test),color='blue')
