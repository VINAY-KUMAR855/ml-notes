# %%
import pandas as pd

# %%
d = pd.read_csv("/home/majji-vinaykumar/Documents/abc.csv")

# %%
df = pd.DataFrame(d)
print(df)
# Out:
#   student  language  science  maths  history
# 0   kumar        90       56     34       34
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 6  carrol        50       90     45       23

# %%
di = {"Name":["vinay","varun","raju"],"ROLL":[2,3,4],"gpa":[23,43,53]}

# %%
df = pd.DataFrame(di)
print(df)
# Out:
#     Name  ROLL  gpa
# 0  vinay     2   23
# 1  varun     3   43
# 2   raju     4   53

# %%
d = [("Viany",2,23),("varun",3,43),("raju",4,53)]

# %%
df = pd.DataFrame(d)
print(df)
# Out:
#        0  1   2
# 0  Viany  2  23
# 1  varun  3  43
# 2   raju  4  53

# %%
d = pd.read_csv("/home/majji-vinaykumar/Documents/abc.csv")
df = pd.DataFrame(d)
print(df)
# Out:
#   student  language  science  maths  history
# 0   kumar        90       56     34       34
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 6  carrol        50       90     45       23

# %%
print(df.describe())
# Out:
#         language    science      maths    history
# count   7.000000   7.000000   7.000000   7.000000
# mean   54.285714  53.000000  43.285714  42.857143
# std    35.523299  22.015146  23.746679  17.062909
# min    10.000000  23.000000  12.000000  23.000000
# 25%    25.000000  39.500000  33.000000  33.000000
# 50%    50.000000  56.000000  45.000000  34.000000
# 75%    90.000000  61.500000  45.000000  55.000000
# max    90.000000  90.000000  90.000000  67.000000

# %%
df.loc[3]
# Out:
# student     janice
# language        20
# science         67
# maths           90
# history         45
# Name: 3, dtype: object

# %%
df.loc[0:3,"science":"history"]
# Out:
#    science  maths  history
# 0       56     34       34
# 1       34     32       67
# 2       23     12       32
# 3       67     90       45

# %%
df
# Out:
#   student  language  science  maths  history
# 0   kumar        90       56     34       34
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 6  carrol        50       90     45       23

# %%
df.iloc[[0,3,5],[1,2]]
# Out:
#    language  science
# 0        90       56
# 3        20       67
# 5        90       45

# %%
df
# Out:
#   student  language  science  maths  history
# 0   kumar        90       56     34       34
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 6  carrol        50       90     45       23

# %%
df.sort_values("maths",ascending=False)
# Out:
#   student  language  science  maths  history
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 6  carrol        50       90     45       23
# 0   kumar        90       56     34       34
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32

# %%
df.sort_values(["student","language"])
# Out:
#   student  language  science  maths  history
# 6  carrol        50       90     45       23
# 3  janice        20       67     90       45
# 1   kevin        10       34     32       67
# 0   kumar        90       56     34       34
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 2   sammy        90       23     12       32

# %%
df["total"]=0

# %%
df.drop(columns="total",inplace=True)

# %%
df
# Out:
#   student  language  science  maths  history
# 0   kumar        90       56     34       34
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 6  carrol        50       90     45       23

# %%
d = pd.read_csv("/home/majji-vinaykumar/Documents/abc1.csv")
df = pd.DataFrame(d)

# %%
df
# Out:
#   student  language  science  maths  history
# 0   kumar      90.0       56   34.0       34
# 1   kevin      10.0       34   32.0       67
# 2   sammy       NaN       23   12.0       32
# 3  janice      20.0       67   90.0       45
# 4   peter      30.0       56   45.0       65
# 5    prem      90.0       45    NaN       34
# 6  carrol      50.0       90   45.0       23

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
df
# Out:
#   student  language  science  maths  history
# 0   kumar      90.0       56   34.0       34
# 1   kevin      10.0       34   32.0       67
# 2   sammy       NaN       23   12.0       32
# 3  janice      20.0       67   90.0       45
# 4   peter      30.0       56   45.0       65
# 5    prem      90.0       45    NaN       34
# 6  carrol      50.0       90   45.0       23

# %%
df.duplicated(columns="language")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.duplicated(columns="language")
#
# TypeError: DataFrame.duplicated() got an unexpected keyword argument 'columns'

# %%
df.fillna(80)
# Out:
#   student  language  science  maths  history
# 0   kumar      90.0       56   34.0       34
# 1   kevin      10.0       34   32.0       67
# 2   sammy      80.0       23   12.0       32
# 3  janice      20.0       67   90.0       45
# 4   peter      30.0       56   45.0       65
# 5    prem      90.0       45   80.0       34
# 6  carrol      50.0       90   45.0       23

# %%
df
# Out:
#   student  language  science  maths  history
# 0   kumar      90.0       56   34.0       34
# 1   kevin      10.0       34   32.0       67
# 2   sammy       NaN       23   12.0       32
# 3  janice      20.0       67   90.0       45
# 4   peter      30.0       56   45.0       65
# 5    prem      90.0       45    NaN       34
# 6  carrol      50.0       90   45.0       23

# %%
df["maths"].fillna(80)
# Out:
# 0    34.0
# 1    32.0
# 2    12.0
# 3    90.0
# 4    45.0
# 5    80.0
# 6    45.0
# Name: maths, dtype: float64

# %%
df
# Out:
#   student  language  science  maths  history
# 0   kumar      90.0       56   34.0       34
# 1   kevin      10.0       34   32.0       67
# 2   sammy       NaN       23   12.0       32
# 3  janice      20.0       67   90.0       45
# 4   peter      30.0       56   45.0       65
# 5    prem      90.0       45    NaN       34
# 6  carrol      50.0       90   45.0       23

# %%
df.dropna()
# Out:
#   student  language  science  maths  history
# 0   kumar      90.0       56   34.0       34
# 1   kevin      10.0       34   32.0       67
# 3  janice      20.0       67   90.0       45
# 4   peter      30.0       56   45.0       65
# 6  carrol      50.0       90   45.0       23

# %%
d = pd.read_csv("/home/majji-vinaykumar/Documents/abc.csv")
df = pd.DataFrame(d)
df
# Out:
#   student  language  science  maths  history
# 0   kumar        90       56     34       34
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 6  carrol        50       90     45       23

# %%
df.loc[df["maths"]>40]
# Out:
#   student  language  science  maths  history
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 6  carrol        50       90     45       23
