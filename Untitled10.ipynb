# %%
import streamlit as st

# %%
st.title('DALL.E - Image Generation - OpenAI')
# Out:
# 2025-08-21 10:19:37.831 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-21 10:19:38.448
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/majji-vinaykumar/tf-env/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-08-21 10:19:38.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-21 10:19:38.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
img_description = st.text_input('Image Desription')
# Out:
# 2025-08-21 10:23:10.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-21 10:23:10.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-21 10:23:10.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-21 10:23:10.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-21 10:23:10.212 Session state does not function when running a script without `streamlit run`
# 2025-08-21 10:23:10.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-21 10:23:10.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-21 10:23:10.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
