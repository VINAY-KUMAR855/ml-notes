# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
d = pd.read_excel("/home/majji-vinaykumar/Documents/ELEGIBLE LIST TO E1.xlsx")
df = pd.DataFrame(d)

# %%
df.head()
# Out:
#    s.no   clg_id              student_name  mat_gp  phy_gp  chem_gp  dob  \
# 0     1  O220041       KOTIKALAPUDI CHARAN    6.25    7.25     6.25  NaN
# 1     2  O220053          BORRA SOMU KUMAR    5.50    5.25     6.00  NaN
# 2     3  O220086       NADIKATTU SIVANJALI    5.25    5.25     5.25  NaN
# 3     4  O220148           RESHMA KATIKALA    6.00    5.25     6.25  NaN
# 4     5  O220227  AREPALLI MOHAN MANIKANTA    6.75    6.25     6.25  NaN
#
#    puc_cgpa  caste  gender STATUS
# 0   7.39583    NaN     NaN   PASS
# 1   6.17375    NaN     NaN   PASS
# 2   6.56167    NaN     NaN   PASS
# 3   6.88792    NaN     NaN   PASS
# 4   6.84750    NaN     NaN   PASS

# %%
df.sort_values('puc_cgpa',ascending=False,inplace=True)

# %%
df.head()
# Out:
#      s.no   clg_id                    student_name  mat_gp  phy_gp  chem_gp  \
# 874   875  O231181                 KORRA   LAVANYA    9.75   10.00    10.00
# 890   891  O231197            MALLI REDDY JOSHNAVI   10.00   10.00     9.75
# 993   994  S231070                   SHAIK FARZANA   10.00   10.00    10.00
# 62     63  O230089         CHINNI JYOTHI SRI DURGA   10.00   10.00     9.75
# 39     40  O230055  GANJANABOYINA DURGA SIRI\nKART   10.00    9.75     9.75
#
#      dob  puc_cgpa  caste  gender STATUS
# 874  NaN      9.95    NaN     NaN   PASS
# 890  NaN      9.94    NaN     NaN   PASS
# 993  NaN      9.93    NaN     NaN   PASS
# 62   NaN      9.92    NaN     NaN   PASS
# 39   NaN      9.92    NaN     NaN   PASS

# %%
df.to_excel("/home/majji-vinaykumar/Documents/SORTED ELEGIBLE LIST TO E1.xlsx")

# %%
df['STATUS'].value_counts()
# Out:
# STATUS
# PASS    1062
# Name: count, dtype: int64

# %%
df.loc[(df["mat_gp"]==10.00)&(df["phy_gp"]==10.00)&(df["chem_gp"]==10.00)]
# Out:
#      s.no   clg_id       student_name  mat_gp  phy_gp  chem_gp  dob  puc_cgpa  \
# 993   994  S231070      SHAIK FARZANA    10.0    10.0     10.0  NaN      9.93
# 602   603  O230861  MAJJI VINAY KUMAR    10.0    10.0     10.0  NaN      9.73
#
#      caste  gender STATUS
# 993    NaN     NaN   PASS
# 602    NaN     NaN   PASS

# %%
# Out:
# ['KORRA   LAVANYA', 'MALLI REDDY JOSHNAVI', 'SHAIK FARZANA', 'CHINNI JYOTHI SRI DURGA', 'GANJANABOYINA DURGA SIRI\nKART', 'GAI VARA LAKSHMI', 'KORADA SAI LIKHITHA', 'BODA SANDEEP KUMAR', 'KUNTAM SINDHU', 'NAMBURU VENKATA NAGA MAHA\nLA', 'KOLLI POOJITHA', 'THOTLI CHARITHA', 'BAINA MANASA SAI', 'CHEKURI BHAVYA SAI', 'NANDYALA LAKSHMI SPOORTHI', 'SHAIK BANAGANAPALLI SALMA', 'CHALLA VYSHNAVI', 'MADANA DEELIP REDDY', 'PAMULAPATI MAHI', 'MACHABATHUNI VISHNU\nVARDHAN', 'PIDEM PRATHYUSHA', 'MALLADI SAHITHI', 'MANNEM PAVANI LAKSHMI', 'DANIKONDA POOJITHA', 'CHANDALURI KEDHARNATH', 'AREPALLI  BHAVANI SANKAR\nNAGARAJU', 'CHIMATA LAKSHMI PRASANNA', 'KATTA NAGA SAI NIKHILA', 'DAVU DURGARAO', 'YARRAM RADHESH REDDY', 'SHAIK BEE BEE RESHMA', 'MAJJI VINAY KUMAR', 'CHANNAMSETTY SNOVICA', 'CHOKKAPU SIMHACHALAM', 'SHAIK MUZKEER', 'DASARI NIRAJA', 'VEMALA ADARSH KUMAR', 'GANGISETTY HEMA BRAHMA KOWSHIK', 'IKA HEMANTH', 'DUDEKULA RAZIYA', 'YEMINENI MOUNIKA', 'V KAVAY SREE', 'YAKKATILI HARSHITHA', 'CHILAKA A
# ...
