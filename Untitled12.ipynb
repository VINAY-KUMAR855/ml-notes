# %%
import os

# %%
DATA_DIR = "/home/majji-vinaykumar/SIH/DATASETS/buffalo_pakistan/Data"

# %%
if os.path.isdir(DATA_DIR):
  print(f"Folder found: {DATA_DIR}")
else:
  print(f"Folder not found: {DATA_DIR}")
# Out:
# Folder found: /home/majji-vinaykumar/SIH/DATASETS/buffalo_pakistan/Data

# %%
def data_count(data_dir):
    breeds = []
    image_counts = []

    if os.path.exists(data_dir):
        for breed_folder in sorted(os.listdir(data_dir)):
            breed_path = os.path.join(data_dir, breed_folder)
            if os.path.isdir(breed_path):
                image_count = len([f for f in os.listdir(breed_path)
                                 if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
                breeds.append(breed_folder)
                image_counts.append(image_count)
                print(f"{breed_folder}: {image_count} images")

    total_images = sum(image_counts)
    print(f"Total Images: {total_images}")
    print(f"Total Breeds: {len(breeds)}")
    print("-" * 40)

# %%
data_count(DATA_DIR)
# Out:
# Khundi: 75 images
# Mix: 137 images
# Neli Ravi: 112 images
# Total Images: 324
# Total Breeds: 3
# ----------------------------------------
